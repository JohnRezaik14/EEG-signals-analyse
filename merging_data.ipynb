# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-22a7bb1e-6805-4bd8-9e65-29cb4f6cb830" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22a7bb1e-6805-4bd8-9e65-29cb4f6cb830">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
AD_HC_N = list(uploaded.keys())[0]
AD_HC = list(uploaded.keys())[1]
Case_Hc_N = list(uploaded.keys())[2]
Case_Hc = list(uploaded.keys())[3]
MCI_AD_N = list(uploaded.keys())[4]
MCI_AD = list(uploaded.keys())[5]
MCI_HC_N = list(uploaded.keys())[6]
MCI_HC = list(uploaded.keys())[7]
# d1 = list(uploaded.keys())[0]
# d2 = list(uploaded.keys())[1]
# d3 = list(uploaded.keys())[2]
# d4 = list(uploaded.keys())[3]

# %%
data1 = pd.read_csv(AD_HC_N)
data2 = pd.read_csv(AD_HC)
data3 = pd.read_csv(Case_Hc_N)
data4 = pd.read_csv(Case_Hc)
data5 = pd.read_csv(MCI_AD_N)
data6 = pd.read_csv(MCI_AD)
data7 = pd.read_csv(MCI_HC_N)
data8 = pd.read_csv(MCI_HC)
dfs=[
    data1,
    data2,
    data3,
    data4,
    data5,
    data6,
    data7,
    data8
     ]
print(dfs)

# data2 = pd.read_csv(AD_HC)

# data4 = pd.read_csv(Case_Hc)

# data6 = pd.read_csv(MCI_AD)

# data8 = pd.read_csv(MCI_HC)
# dfs=[

#     data2,

#     data4,

#     data6,

#     data8
#      ]
# print(dfs)
# Out:
# [            experiment       Four_1       Four_2       Four_3       Four_4  \
# 0    Patient_1_Control   -30.102930  -157.309777   -16.886907    -1.109617
# 1   Patient_10_Control   -63.018572   -47.012826    32.386004    31.315686
# 2   Patient_11_Control   -23.649611   -13.187461     4.245103     0.400029
# 3   Patient_12_Control  -348.352466   -19.019356    -1.982487   -13.245628
# 4   Patient_13_Control   -31.212714  -193.711249  -172.715226     4.335222
# ..                 ...          ...          ...          ...          ...
# 67  Patient_19_Control  -183.366231  -348.151420  -679.258492  -437.337968
# 68  Patient_20_Control  1020.509432 -3868.685320   891.748953 -6815.587289
# 69  Patient_21_Control  -703.029151   175.975564  4463.569206  3132.059018
# 70  Patient_22_Control   800.612745    74.115674    52.365794   267.581081
# 71  Patient_23_Control    -9.704586   -30.309598  -193.400586   -10.817145
#
# ...

# %%
merged_df = None
for df in dfs:
  if merged_df is None:
        merged_df = df
  else:
        merged_df = pd.concat(dfs, ignore_index=True)

print(merged_df)
merged_df = merged_df.drop_duplicates()
print(merged_df)
# Out:
#              experiment       Four_1       Four_2       Four_3       Four_4  \
# 0     Patient_1_Control   -30.102930  -157.309777   -16.886907    -1.109617
# 1    Patient_10_Control   -63.018572   -47.012826    32.386004    31.315686
# 2    Patient_11_Control   -23.649611   -13.187461     4.245103     0.400029
# 3    Patient_12_Control  -348.352466   -19.019356    -1.982487   -13.245628
# 4    Patient_13_Control   -31.212714  -193.711249  -172.715226     4.335222
# ..                  ...          ...          ...          ...          ...
# 649  Patient_19_Control  -183.449000  -348.000000  -679.328000  -437.324000
# 650  Patient_20_Control  1020.508000 -3868.750000   891.668000 -6815.695000
# 651  Patient_21_Control  -702.875000   175.895000  4463.504000  3132.160000
# 652  Patient_22_Control   800.555000    74.148000    52.426000   267.680000
# 653  Patient_23_Control    -9.859000   -30.340000  -193.691000   -10.734000
#
# ...

# %%
for df in dfs:
    df.loc[df.iloc[:,0].str.contains('MCI'), df.columns[-1]] = 'MCI'
    df.loc[df.iloc[:,0].str.contains('AD'), df.columns[-1]] = 'AD'
    df.loc[df.iloc[:,0].str.contains('Control'), df.columns[-1]] = 'Control'
merged_labeled_df = None
for df in dfs:
  if merged_labeled_df is None:
        merged_labeled_df = df
  else:
        merged_labeled_df = pd.concat(dfs, ignore_index=True)
        All_Data = merged_labeled_df.drop_duplicates()
print(merged_labeled_df.shape)
print(All_Data)
# Out:
# (654, 306)
#              experiment       Four_1       Four_2       Four_3       Four_4  \
# 0     Patient_1_Control   -30.102930  -157.309777   -16.886907    -1.109617
# 1    Patient_10_Control   -63.018572   -47.012826    32.386004    31.315686
# 2    Patient_11_Control   -23.649611   -13.187461     4.245103     0.400029
# 3    Patient_12_Control  -348.352466   -19.019356    -1.982487   -13.245628
# 4    Patient_13_Control   -31.212714  -193.711249  -172.715226     4.335222
# ..                  ...          ...          ...          ...          ...
# 589  Patient_19_Control  -183.562460  -348.104467  -679.531465  -437.275657
# 590  Patient_20_Control  1020.431408 -3868.599793   891.649390 -6815.725353
# 591  Patient_21_Control  -703.008887   176.056724  4463.496229  3132.266113
# 592  Patient_22_Control   800.470068    74.365532    52.387832   267.765722
# 593  Patient_23_Control    -9.908695   -30.370649  -193.821754   -10.834464
#
# ...

# %%
save_path = "/content/drive/MyDrive/John's SRTA training/Data/original_noise_data.csv"
import os
# for idx, df in enumerate(dfs):
    # # filename = f'dataframe_{idx}.csv'
    # full_path = os.path.join(save_path, filename)

merged_labeled_df.to_csv(save_path,index=False)
